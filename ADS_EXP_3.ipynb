# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyapandey1/ADS-Lab/blob/main/ADS_EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline

# %%
SP500_Comp = pd.read_csv('/content/sp500_companies.csv')
SP500_Comp.head(10)
# Out:
#   Exchange Symbol                    Shortname                 Longname  \
# 0      NMS   MSFT        Microsoft Corporation    Microsoft Corporation
# 1      NMS   AAPL                   Apple Inc.               Apple Inc.
# 2      NMS   NVDA           NVIDIA Corporation       NVIDIA Corporation
# 3      NMS   AMZN             Amazon.com, Inc.         Amazon.com, Inc.
# 4      NMS   GOOG                Alphabet Inc.            Alphabet Inc.
# 5      NMS  GOOGL                Alphabet Inc.            Alphabet Inc.
# 6      NMS   META         Meta Platforms, Inc.     Meta Platforms, Inc.
# 7      NYQ  BRK-B  Berkshire Hathaway Inc. New  Berkshire Hathaway Inc.
# 8      NYQ    LLY        Eli Lilly and Company    Eli Lilly and Company
# 9      NMS   AVGO                Broadcom Inc.            Broadcom Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology       Software - Infrastructure        415.50
# 1              Technology            Consumer Electronics        179.66
# 2              Technology                  Semiconductors        822.79
# 3       Consumer Cyclical                 Internet Retail        178.22
# 4  Communication Services  Internet Content & Information        138.08
# 5  Communication Services  Internet Content & Information        137.14
# 6  Communication Services  Internet Content & Information        502.30
# 7      Financial Services         Insurance - Diversified        407.11
# 8              Healthcare    Drug Manufacturers - General        782.12
# 9              Technology                  Semiconductors       1399.17
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3087347744768  1.184270e+11          0.176        Redmond    WA
# 1  2774291709952  1.301090e+11          0.021      Cupertino    CA
# 2  2056974893056  3.448000e+10          2.653    Santa Clara    CA
# 3  1851242446848  8.551500e+10          0.139        Seattle    WA
# 4  1710397063168  1.001720e+11          0.135  Mountain View    CA
# 5  1710396407808  1.001720e+11          0.135  Mountain View    CA
# 6  1280568590336  6.138100e+10          0.247     Menlo Park    CA
# 7   881527422976  1.356820e+11          0.196          Omaha    NE
# 8   743142260736  1.231460e+10          0.281   Indianapolis    IN
# 9   648404795392  2.020300e+10          0.164      Palo Alto    CA
#
#          Country  Fulltimeemployees  \
# 0  United States           221000.0
# 1  United States           161000.0
# 2  United States            29600.0
# 3  United States          1525000.0
# 4  United States           182502.0
# 5  United States           182502.0
# 6  United States            67317.0
# 7  United States           396500.0
# 8  United States            43000.0
# 9  United States            20000.0
#
#                                  Longbusinesssummary    Weight
# 0  Microsoft Corporation develops and supports so...  0.064953
# 1  Apple Inc. designs, manufactures, and markets ...  0.058367
# 2  NVIDIA Corporation provides graphics, and comp...  0.043276
# 3  Amazon.com, Inc. engages in the retail sale of...  0.038947
# 4  Alphabet Inc. offers various products and plat...  0.035984
# 5  Alphabet Inc. offers various products and plat...  0.035984
# 6  Meta Platforms, Inc. engages in the developmen...  0.026941
# 7  Berkshire Hathaway Inc., through its subsidiar...  0.018546
# 8  Eli Lilly and Company discovers, develops, and...  0.015635
# 9  Broadcom Inc. designs, develops, and supplies ...  0.013641

# %%
SP_corr = SP500_Comp.corr()
mask = np.zeros_like(SP_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(12, 10))
    ax = sns.heatmap(SP_corr, mask=mask, vmax=1, vmin=-1, linewidths=.5, square=True, cmap='coolwarm', annot=True)
    plt.title('Correlation Heatmap of S&P 500 Companies dataset', fontsize = 15)
    plt.yticks(rotation=0)
    plt.tight_layout()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
SP500_Comp.groupby('Exchange').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
d2 = sns.displot(data=SP500_Comp, x='Currentprice', kde=True, height=8, aspect=1.6, bins=100, binrange=(0, 2100), color='dodgerblue')
d2.set(xlabel='Current Price')
plt.xlim(0, 2100)
# Out:
# (0.0, 2100.0)

# %%
d1 = sns.displot(data=SP500_Comp, x='Revenuegrowth', height=8, aspect=1.6, kde=True, color='dodgerblue')
d1.set(xlabel='Revenue Growth')
plt.xlim(-0.7,3)
# Out:
# (-0.7, 3.0)

# %%
f = {'Revenuegrowth':['mean'], 'Marketcap':['sum'], 'Longname':['count']}

sector_breakdown = SP500_Comp.groupby('Sector').agg(f)
sector_breakdown.columns = sector_breakdown.columns.get_level_values(0)
sector_breakdown = sector_breakdown.reset_index()
sector_breakdown = sector_breakdown.sort_values('Longname', ascending=False)

fig = plt.figure(num=None, figsize=(14, 6), dpi=100, facecolor='w', edgecolor='k')

plt.subplot(1, 3, 1)
ax1 = sns.barplot(x="Longname", y="Sector", data=sector_breakdown, palette=('coolwarm'))
ax1.set_xlabel('Number of companies', weight='bold')
ax1.set_ylabel('Sector', weight = 'bold')
ax1.set_title('SECTOR BREAKDOWN\n', weight='bold').set_fontsize('18')

plt.subplot(1, 3, 2)
ax2 = sns.barplot(x="Marketcap", y="Sector", data=sector_breakdown, palette=('Wistia'))
ax2.set_xlabel('Total Market Cap', weight='bold')
ax2.set_ylabel('')
ax2.set_yticks([])

plt.subplot(1, 3, 3)
ax2 = sns.barplot(x="Revenuegrowth", y="Sector", data=sector_breakdown, palette=('OrRd_r'))
ax2.set_xlabel('Revenue Growth', weight='bold')
ax2.set_ylabel('')
ax2.set_yticks([])

sns.despine()
plt.tight_layout();
